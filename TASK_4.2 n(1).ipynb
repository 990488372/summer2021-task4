# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img1 = cv2.imread("linux.jpg")
img2 = cv2.imread("windows.png")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
#cv2.imshow("image1",img1)
#cv2.waitKey(0) == 13
#cv2.destroyAllWindows()

# %%
plt.imshow(img1) 
img1.shape
# Out:
# (244, 206, 3)

# %%
#cv2.imshow("image2",img2)
#cv2.waitKey(0) == 13
#cv2.destroyAllWindows()
plt.imshow(img2)
img2.shape
# Out:
# (211, 239, 3)

# %%
linux_array = img1.copy()
windows_array = img2.copy()

# %%
linux_array_cropped = linux_array[10:100, 50:150]
linux_array_cropped.shape
# Out:
# (90, 100, 3)

# %%
# cv2.imshow("CROPPED", img1_array_cropped)
# cv2.waitKey(0) == 13
# cv2.destroyAllWindows()
plt.imshow(linux_array_cropped)
cv2.imwrite("image1.jpg",linux_array_cropped)
# Out:
# True

# %%
windows_array_cropped = windows_array[60:160, 70:170]
windows_array_cropped.shape

# %%
# cv2.imshow("CROPPED", img2_array_cropped)
# cv2.waitKey(0) == 13
# cv2.destroyAllWindows()
plt.imshow(windows_array_cropped)
cv2.imwrite("image2.jpg",img2_array_cropped)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-abcdd72da964> in <module>
#       2 # cv2.waitKey(0) == 13
#       3 # cv2.destroyAllWindows()
# ----> 4 plt.imshow(windows_array_cropped)
#       5 cv2.imwrite("image2.jpg",img2_array_cropped)
#
# NameError: name 'windows_array_cropped' is not defined

# %%
img1[60:160, 70:170] = windows_array_cropped
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1a7bcdb61c10> in <module>
# ----> 1 img1[60:160, 70:170] = windows_array_cropped
#
# NameError: name 'windows_array_cropped' is not defined

# %%
# cv2.imshow("CROPPED", img1)
# cv2.waitKey(0) == 13
# cv2.destroyAllWindows()
plt.imshow(img1)

# %%
img2[10:100, 50:150] = linux_array_cropped

# %%
# cv2.imshow("CROPPED", img2)
# cv2.waitKey(0) == 13
# cv2.destroyAllWindows()
plt.imshow(img2)
